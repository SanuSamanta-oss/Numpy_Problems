# %% [markdown]
# ##### Given:
# ##### python `arr = np.array([2, 4, 6, 8, 10])`
# ##### Multiply every element by *2*.

# %%
import numpy as np
arr = np.array([2,4,6,8,10])
print(arr*2)
# Out:
# [ 4  8 12 16 20]
