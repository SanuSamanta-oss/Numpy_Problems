# %% [markdown]
# #### <i>Create a array and print sum of the elements in the array</i>

# %%
import numpy as np

lists = np.array([10,20,30,40,50])

print(lists)
sum = np.sum(lists)
print("Sum of the elements: ", sum)
# Out:
# [10 20 30 40 50]
# Sum of the elements:  150
