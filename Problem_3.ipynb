# %% [markdown]
# #### <i>Create a Numpy array containing elements and find mean </i>

# %%
import numpy as np
elements = np.array([5,10,15,20,25])
Mean_of_array = np.mean(elements)
print("Mean of the array is : ",Mean_of_array)
# Out:
# Mean of the array is :  15.0
