# %% [markdown]
# <i>
#
# ##### Given the array : python
# ##### `arr = np.array([10,20,30,40,50])`
# ##### Print the first element and last element
#
# </i>

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
first_element = arr[0]
last_element = arr[4]

print("Fisrt element:",first_element)
print("Last element:", last_element)
# Out:
# Fisrt element: 10
# Last element: 50
